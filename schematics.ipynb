# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes with updated names
nodes = ['Raster Data', 'Time Data', 'Image Data', 'Raster Encoder', 'TS Encoder', 'Image Encoder', 'Feature Vector', 'kNN', 'Binary Species Vector']
G.add_nodes_from(nodes)

# Add edges with updated node names
edges = [
    ('Raster Data', 'Raster Encoder'),
    ('Time Data', 'TS Encoder'),
    ('Image Data', 'Image Encoder'),
    ('Raster Encoder', 'Feature Vector'),
    ('TS Encoder', 'Feature Vector'),
    ('Image Encoder', 'Feature Vector'),
    ('Feature Vector', 'kNN'),
    ('kNN', 'Binary Species Vector')
]
G.add_edges_from(edges)

# Define node positions
pos = {
    'Raster Data': (0, 3),
    'Time Data': (0, 2),
    'Image Data': (0, 1),
    'Raster Encoder': (1, 3),
    'TS Encoder': (1, 2),
    'Image Encoder': (1, 1),
    'Feature Vector': (2, 2),
    'kNN': (3, 2),
    'Binary Species Vector': (4, 2)
}

# Draw the graph with white nodes and black outlines
plt.figure(figsize=(8, 7))
nx.draw(G, pos, with_labels=False, node_size=3000, node_color='white', edgecolors='black', font_size=10, font_weight='bold', edge_color='black', arrows=True)

# Add labels outside the nodes
for node, (x, y) in pos.items():
    plt.text(x, y+0.15, node, fontsize=10, ha='center')

plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes with updated names
nodes = ['Image Data', 'Time Series Data', 'Environmental Data', 'Image Feature Extractor', 'Temporal Feature Extractor', '           Environmental Feature Extractor', 'Feature Vector', 'Two Layer FFNN', 'Binary Species Vector']
G.add_nodes_from(nodes)

# Add edges with updated node names
edges = [
    ('Image Data', 'Image Feature Extractor'),
    ('Time Series Data', 'Temporal Feature Extractor'),
    ('Environmental Data', '           Environmental Feature Extractor'),
    ('Image Feature Extractor', 'Feature Vector'),
    ('Temporal Feature Extractor', 'Feature Vector'),
    ('           Environmental Feature Extractor', 'Feature Vector'),
    ('Feature Vector', 'Two Layer FFNN'),
    ('Two Layer FFNN', 'Binary Species Vector')
]
G.add_edges_from(edges)

# Define node positions
pos = {
    'Image Data': (0, 3),
    'Time Series Data': (0, 2),
    'Environmental Data': (0, 1),
    'Image Feature Extractor': (1, 3),
    'Temporal Feature Extractor': (1, 2),
    '           Environmental Feature Extractor': (1, 1),
    'Feature Vector': (2, 2),
    'Two Layer FFNN': (3, 2),
    'Binary Species Vector': (4, 2)
}

# Draw the graph with white nodes and black outlines
plt.figure(figsize=(8, 7))
nx.draw(G, pos, with_labels=False, node_size=3000, node_color='white', edgecolors='black', font_size=10, font_weight='bold', edge_color='black', arrows=True)

# Add labels outside the nodes
for node, (x, y) in pos.items():
    plt.text(x, y+0.15, node, fontsize=10, ha='center')

plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes with updated names
nodes = ['Raster Data', 'Time Series Data', 'Image Data', 'FFNN', 'MultiLabelLSTM', 'ResNet34', 'Individual Prediction Vectors', 'Mean Model', 'Binary Species Vector']
G.add_nodes_from(nodes)

# Add edges with updated node names
edges = [
    ('Raster Data', 'FFNN'),
    ('Time Series Data', 'MultiLabelLSTM'),
    ('Image Data', 'ResNet34'),
    ('FFNN', 'Individual Prediction Vectors'),
    ('MultiLabelLSTM', 'Individual Prediction Vectors'),
    ('ResNet34', 'Individual Prediction Vectors'),
    ('Individual Prediction Vectors', 'Mean Model'),
    ('Mean Model', 'Binary Species Vector')
]
G.add_edges_from(edges)

# Define node positions
pos = {
    'Raster Data': (0, 3),
    'Time Series Data': (0, 2),
    'Image Data': (0, 1),
    'FFNN': (1, 3),
    'MultiLabelLSTM': (1, 2),
    'ResNet34': (1, 1),
    'Individual Prediction Vectors': (2, 2),
    'Mean Model': (3, 2),
    'Binary Species Vector': (4, 2)
}

# Draw the graph with white nodes and black outlines
plt.figure(figsize=(8, 7))
nx.draw(G, pos, with_labels=False, node_size=3000, node_color='white', edgecolors='black', font_size=10, font_weight='bold', edge_color='black', arrows=True)

# Add labels outside the nodes
for node, (x, y) in pos.items():
    plt.text(x, y+0.15, node, fontsize=10, ha='center')

plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes with updated names
nodes = ['Survey Locations', 'Landsat Data', 'Bioclimatic Data', 'Sentinel Data', 'ResNet18 (Landsat)', 'ResNet18 (Bioclimatic)', 'Swin-T (Sentinel)', 'Node Features', 'Graph Construction', 'GraphSAGE Model', 'Species Presence Vector']
G.add_nodes_from(nodes)

# Add edges with updated node names
edges = [
    ('Survey Locations', 'Landsat Data'),
    ('Survey Locations', 'Bioclimatic Data'),
    ('Survey Locations', 'Sentinel Data'),
    ('Landsat Data', 'ResNet18 (Landsat)'),
    ('Bioclimatic Data', 'ResNet18 (Bioclimatic)'),
    ('Sentinel Data', 'Swin-T (Sentinel)'),
    ('ResNet18 (Landsat)', 'Node Features'),
    ('ResNet18 (Bioclimatic)', 'Node Features'),
    ('Swin-T (Sentinel)', 'Node Features'),
    ('Node Features', 'Graph Construction'),
    ('Graph Construction', 'GraphSAGE Model'),
    ('GraphSAGE Model', 'Species Presence Vector')
]
G.add_edges_from(edges)

# Define node positions
pos = {
    'Survey Locations': (0, 2),
    'Landsat Data': (1, 3),
    'Bioclimatic Data': (1, 2),
    'Sentinel Data': (1, 1),
    'ResNet18 (Landsat)': (2, 3),
    'ResNet18 (Bioclimatic)': (2, 2),
    'Swin-T (Sentinel)': (2, 1),
    'Node Features': (3, 2),
    'Graph Construction': (4, 2),
    'GraphSAGE Model': (5, 2),
    'Species Presence Vector': (6, 2)
}

# Draw the graph with white nodes and black outlines
plt.figure(figsize=(12, 8))
nx.draw(G, pos, with_labels=False, node_size=3000, node_color='white', edgecolors='black', font_size=10, font_weight='bold', edge_color='black', arrows=True)

# Add labels outside the nodes
for node, (x, y) in pos.items():
    plt.text(x, y+0.15, node, fontsize=10, ha='center')

plt.title('Graph-based Species Presence Prediction Framework', fontsize=16, pad=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes with updated names
nodes = ['Landsat Tensor', 'Bioclim Tensor', 'Sentinel Image', 'ResNet18 (Landsat)', 'ResNet18 (Bioclimatic)', 'Swin-T (Sentinel)', 'Node Embeddings', 'GraphSAGE Model', 'Binary Species Vector', 'Survey Coordinates', 'Edge features']
G.add_nodes_from(nodes)

# Add edges with updated node names
edges = [
    ('Landsat Tensor', 'ResNet18 (Landsat)'),
    ('Bioclim Tensor', 'ResNet18 (Bioclimatic)'),
    ('Sentinel Image', 'Swin-T (Sentinel)'),
    ('ResNet18 (Landsat)', 'Node Embeddings'),
    ('ResNet18 (Bioclimatic)', 'Node Embeddings'),
    ('Swin-T (Sentinel)', 'Node Embeddings'),
    ('Node Embeddings', 'GraphSAGE Model'),
    ('GraphSAGE Model', 'Binary Species Vector'),
    ('Survey Coordinates', 'Edge features'),
    ('Edge features', 'GraphSAGE Model')
]
G.add_edges_from(edges)

# Define node positions
pos = {
    'Landsat Tensor': (0, 3),
    'Bioclim Tensor': (0, 2),
    'Sentinel Image': (0, 1),
    'ResNet18 (Landsat)': (1, 3),
    'ResNet18 (Bioclimatic)': (1, 2),
    'Swin-T (Sentinel)': (1, 1),
    'Node Embeddings': (2, 2),
    'GraphSAGE Model': (3, 2),
    'Species Vector': (4, 2),
    'Survey Coordinates': (0, 0),
    'Edge features': (2, 0)
}

# Draw the graph with white nodes and black outlines
plt.figure(figsize=(8, 7))
nx.draw(G, pos, with_labels=False, node_size=3000, node_color='white', edgecolors='black', font_size=10, font_weight='bold', edge_color='black', arrows=True)

# Add labels outside the nodes
for node, (x, y) in pos.items():
    plt.text(x, y+0.25, node, fontsize=10, ha='center')


plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes with updated names
nodes = ['Raster Data', 'Time Series Data', 'Image Data', 'Top k Species', 
         'Feature Vector','Target Vector 1', 'Target Vector ...', 'Target Vector k',
         'RUS 1', 'RUS ...','RUS k', 
         'Classifier 1', 'Classifier ...', 'Classifier k', 
         'Species Presence Vector']
G.add_nodes_from(nodes)

# Add edges with updated node names
edges = [
    ('Raster Data', 'Feature Vector'),
    ('Time Series Data', 'Feature Vector'),
    ('Image Data', 'Feature Vector'),
    ('Top k Species', 'Target Vector 1'),
    ('Top k Species', 'Target Vector ...'),
    ('Top k Species', 'Target Vector k'),
    ('Feature Vector', 'RUS 1'),
    ('Feature Vector', 'RUS ...'),
    ('Feature Vector', 'RUS k'),
    ('Target Vector 1', 'RUS 1'),
    ('Target Vector ...', 'RUS ...'),
    ('Target Vector k', 'RUS k'),
    ('RUS 1', 'Classifier 1'),
    ('RUS ...', 'Classifier ...'),
    ('RUS k', 'Classifier k'),
    ('Classifier 1', 'Species Presence Vector'),
    ('Classifier ...', 'Species Presence Vector'),
    ('Classifier k', 'Species Presence Vector')
]
G.add_edges_from(edges)

# Define node positions
pos = {
    'Raster Data': (0, 4),
    'Time Series Data': (0, 3),
    'Image Data': (0, 2),
    'Top k Species': (0, 1),
    'Feature Vector': (1, 4),
    'Target Vector 1': (1, 3),
    'Target Vector ...': (1, 2),
    'Target Vector k': (1, 1),
    'RUS 1': (2, 3),
    'RUS ...': (2, 2),
    'RUS k': (2, 1),
    'Classifier 1': (3, 3),
    'Classifier ...': (3, 2),
    'Classifier k': (3, 1),
    'Species Presence Vector': (4, 2)
}

# Draw the graph with white nodes and black outlines
plt.figure(figsize=(8, 7))
nx.draw(G, pos, with_labels=False, node_size=3000, node_color='white', edgecolors='black', font_size=10, font_weight='bold', edge_color='black', arrows=True)

# Add labels outside the nodes
for node, (x, y) in pos.items():
    plt.text(x, y+0.30, node, fontsize=10, ha='center')

plt.show()

# %%
# baseline

import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes with updated names
nodes = ['Landsat Tensor', 'Bioclim Tensor', 'Sentinel Image', 'ResNet18 (Landsat)', 'ResNet18 (Bioclimatic)', 'Swin-T (Sentinel)', 'Node Embeddings', 'GraphSAGE Model', 'Binary Species Vector']
G.add_nodes_from(nodes)

# Add edges with updated node names
edges = [
    ('Landsat Tensor', 'ResNet18 (Landsat)'),
    ('Bioclim Tensor', 'ResNet18 (Bioclimatic)'),
    ('Sentinel Image', 'Swin-T (Sentinel)'),
    ('ResNet18 (Landsat)', 'Node Embeddings'),
    ('ResNet18 (Bioclimatic)', 'Node Embeddings'),
    ('Swin-T (Sentinel)', 'Node Embeddings'),
    ('Node Embeddings', 'GraphSAGE Model'),
    ('GraphSAGE Model', 'Species Vector'),
    ('Survey Coordinates', 'Edge features'),
    ('Edge features', 'GraphSAGE Model')
]
G.add_edges_from(edges)

# Define node positions
pos = {
    'Landsat Tensor': (0, 3),
    'Bioclim Tensor': (0, 2),
    'Sentinel Image': (0, 1),
    'ResNet18 (Landsat)': (1, 3),
    'ResNet18 (Bioclimatic)': (1, 2),
    'Swin-T (Sentinel)': (1, 1),
    'Node Embeddings': (2, 2),
    'GraphSAGE Model': (3, 2),
    'Species Vector': (4, 2),
    'Survey Coordinates': (0, 0),
    'Edge features': (2, 0)
}

# Draw the graph with white nodes and black outlines
plt.figure(figsize=(8, 7))
nx.draw(G, pos, with_labels=False, node_size=3000, node_color='white', edgecolors='black', font_size=10, font_weight='bold', edge_color='black', arrows=True)

# Add labels outside the nodes
for node, (x, y) in pos.items():
    plt.text(x, y+0.25, node, fontsize=10, ha='center')


plt.show()

# %% [markdown]
# # Final Versions

# %%
# GraphSAGE

import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes with updated names
nodes = ['Landsat Tensor', 'Bioclim Tensor', 'Sentinel Image', 'ResNet18 (Landsat)', 'ResNet18 (Bioclimatic)', 'Swin-T (Sentinel)', 'Node Embeddings', 'GraphSAGE Model', 'Binary Species Vector', 'Survey Coordinates', 'Edge features']
G.add_nodes_from(nodes)

# Add edges with updated node names
edges = [
    ('Landsat Tensor', 'ResNet18 (Landsat)'),
    ('Bioclim Tensor', 'ResNet18 (Bioclimatic)'),
    ('Sentinel Image', 'Swin-T (Sentinel)'),
    ('ResNet18 (Landsat)', 'Node Embeddings'),
    ('ResNet18 (Bioclimatic)', 'Node Embeddings'),
    ('Swin-T (Sentinel)', 'Node Embeddings'),
    ('Node Embeddings', 'GraphSAGE Model'),
    ('GraphSAGE Model', 'Binary Species Vector'),
    ('Survey Coordinates', 'Edge features'),
    ('Edge features', 'GraphSAGE Model')
]
G.add_edges_from(edges)

# Define node positions
pos = {
    'Landsat Tensor': (0, 3),
    'Bioclim Tensor': (0, 2),
    'Sentinel Image': (0, 1),
    'ResNet18 (Landsat)': (1, 3),
    'ResNet18 (Bioclimatic)': (1, 2),
    'Swin-T (Sentinel)': (1, 1),
    'Node Embeddings': (2, 2),
    'GraphSAGE Model': (3, 2),
    'Binary Species Vector': (4, 2),
    'Survey Coordinates': (0, 0),
    'Edge features': (2, 0)
}

# Draw the graph with white nodes and black outlines
plt.figure(figsize=(8, 7))
nx.draw(G, pos, with_labels=False, node_size=3000, node_color='white', edgecolors='black', font_size=10, font_weight='bold', edge_color='black', arrows=True)

# Add labels outside the nodes
for node, (x, y) in pos.items():
    plt.text(x, y+0.25, node, fontsize=10, ha='center')


plt.show()

# %%
# Baseline

# Create a directed graph
G = nx.DiGraph()

# Add nodes with updated names
nodes = ['Landsat Tensor', 'Bioclim Tensor', 'Sentinel Image', 'ResNet18 (Landsat)', 'ResNet18 (Bioclimatic)', 'Swin-T (Sentinel)', 'Feature Vector', 'Two-Layer FFNN', 'Binary Species Vector']
G.add_nodes_from(nodes)

# Add edges with updated node names
edges = [
    ('Landsat Tensor', 'ResNet18 (Landsat)'),
    ('Bioclim Tensor', 'ResNet18 (Bioclimatic)'),
    ('Sentinel Image', 'Swin-T (Sentinel)'),
    ('ResNet18 (Landsat)', 'Feature Vector'),
    ('ResNet18 (Bioclimatic)', 'Feature Vector'),
    ('Swin-T (Sentinel)', 'Feature Vector'),
    ('Feature Vector', 'Two-Layer FFNN'),
    ('Two-Layer FFNN', 'Binary Species Vector'),
   
]
G.add_edges_from(edges)

# Define node positions
pos = {
    'Landsat Tensor': (0, 3),
    'Bioclim Tensor': (0, 2),
    'Sentinel Image': (0, 1),
    'ResNet18 (Landsat)': (1, 3),
    'ResNet18 (Bioclimatic)': (1, 2),
    'Swin-T (Sentinel)': (1, 1),
    'Feature Vector': (2, 2),
    'Two-Layer FFNN': (3, 2),
    'Binary Species Vector': (4, 2),

}

# Draw the graph with white nodes and black outlines
plt.figure(figsize=(8, 7))
nx.draw(G, pos, with_labels=False, node_size=3000, node_color='white', edgecolors='black', font_size=10, font_weight='bold', edge_color='black', arrows=True)

# Add labels outside the nodes
for node, (x, y) in pos.items():
    plt.text(x, y+0.25, node, fontsize=10, ha='center')


plt.show()

# %%
# FME

# Create a directed graph
G = nx.DiGraph()

# Add nodes with updated names
nodes = ['Landsat Tensor', 'Bioclim Tensor', 'Sentinel Image', 'ResNet18 (Landsat) + FFNN', 'ResNet18 (Bioclimatic) + FFNN', 'Swin-T (Sentinel) + FFNN', 'Individual Feature Vectors', 'Averaging', 'Binary Species Vector']
G.add_nodes_from(nodes)

# Add edges with updated node names
edges = [
    ('Landsat Tensor', 'ResNet18 (Landsat) + FFNN'),
    ('Bioclim Tensor', 'ResNet18 (Bioclimatic) + FFNN'),
    ('Sentinel Image', 'Swin-T (Sentinel) + FFNN'),
    ('ResNet18 (Landsat) + FFNN', 'Individual Feature Vectors'),
    ('ResNet18 (Bioclimatic) + FFNN', 'Individual Feature Vectors'),
    ('Swin-T (Sentinel) + FFNN', 'Individual Feature Vectors'),
    ('Individual Feature Vectors', 'Averaging'),
    ('Averaging', 'Binary Species Vector'),
   
]
G.add_edges_from(edges)

# Define node positions
pos = {
    'Landsat Tensor': (0, 3),
    'Bioclim Tensor': (0, 2),
    'Sentinel Image': (0, 1),
    'ResNet18 (Landsat) + FFNN': (1, 3),
    'ResNet18 (Bioclimatic) + FFNN': (1, 2),
    'Swin-T (Sentinel) + FFNN': (1, 1),
    'Individual Feature Vectors': (2, 2),
    'Averaging': (3, 2),
    'Binary Species Vector': (4, 2),

}

# Draw the graph with white nodes and black outlines
plt.figure(figsize=(8, 7))
nx.draw(G, pos, with_labels=False, node_size=3000, node_color='white', edgecolors='black', font_size=10, font_weight='bold', edge_color='black', arrows=True)

# Add labels outside the nodes
for i, (node, (x, y)) in enumerate(pos.items()):
    if i == 6:
        z = 0.15
    else:
        z = 0

    plt.text(x, y+0.25+z, node, fontsize=10, ha='center')


plt.show()

# %%
# top k bc


# Create a directed graph
G = nx.DiGraph()

# Add nodes with updated names
nodes = ['Tabular Environmental Data', 'Top k Species', 
         'Feature and Target Vector 1', 'Feature and Target Vector ...', 'Feature and Target Vector k',
         'RUS 1', 'RUS ...','RUS k', 
         'Classifier 1', 'Classifier ...', 'Classifier k', 
         'Binary Species Vector']
G.add_nodes_from(nodes)

# Add edges with updated node names
edges = [
    ('Tabular Environmental Data', 'Feature and Target Vector 1'),
    ('Tabular Environmental Data', 'Feature and Target Vector ...'),
    ('Tabular Environmental Data', 'Feature and Target Vector k'),
    ('Top k Species', 'Feature and Target Vector 1'),
    ('Top k Species', 'Feature and Target Vector ...'),
    ('Top k Species', 'Feature and Target Vector k'),
    ('Feature and Target Vector 1', 'RUS 1'),
    ('Feature and Target Vector ...', 'RUS ...'),
    ('Feature and Target Vector k', 'RUS k'),
    ('RUS 1', 'Classifier 1'),
    ('RUS ...', 'Classifier ...'),
    ('RUS k', 'Classifier k'),
    ('Classifier 1', 'Binary Species Vector'),
    ('Classifier ...', 'Binary Species Vector'),
    ('Classifier k', 'Binary Species Vector')
]
G.add_edges_from(edges)

# Define node positions
pos = {
    'Tabular Environmental Data': (0, 3),
    'Top k Species': (0, 1),
    'Feature and Target Vector 1': (1, 3),
    'Feature and Target Vector ...': (1, 2),
    'Feature and Target Vector k': (1, 1),
    'RUS 1': (2, 3),
    'RUS ...': (2, 2),
    'RUS k': (2, 1),
    'Classifier 1': (3, 3),
    'Classifier ...': (3, 2),
    'Classifier k': (3, 1),
    'Binary Species Vector': (4, 2)
}

# Draw the graph with white nodes and black outlines
plt.figure(figsize=(8, 7))
nx.draw(G, pos, with_labels=False, node_size=3000, node_color='white', edgecolors='black', font_size=10, font_weight='bold', edge_color='black', arrows=True)

# Add labels outside the nodes
for i, (node, (x, y)) in enumerate(pos.items()):
    if i == 2:
        z = -0.1
    else:
        z = 0

    plt.text(x, y+0.25+z, node, fontsize=10, ha='center')

plt.show()
